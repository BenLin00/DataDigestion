# %%
import pandas as pd
import statsmodels.api as sm
import folium
import numpy as np

# %%
df = pd.read_csv("heatmap.csv")

# %%
# numerical data from this csv file is described here:

df1 = df[['NAME10', 'INTPTLAT10', 'INTPTLON10', 'Partner Count', '2019 FI Rate', '2019 FI Population', 'PublicTransportPercent', 'PovertyPercent', 'HealthInsurPercent','NonEnglishPer', 'HHMedianIncome', 'EduHSPer']]
df1.head()
# Out:
#     NAME10  INTPTLAT10  INTPTLON10  Partner Count  2019 FI Rate  \
# 0  4402.02   38.856771  -77.236125              0          10.4
# 1  4402.01   38.873317  -77.222164              0           9.1
# 2  4506.01   38.856687  -77.208349              0           0.3
# 3  4507.02   38.837091  -77.203370              2          10.0
# 4  4507.01   38.843259  -77.213301              0           1.6
#
#    2019 FI Population  PublicTransportPercent  PovertyPercent  \
# 0                 625                     9.7            16.3
# 1                 282                    17.1             4.7
# 2                  13                     7.3             2.9
# 3                 518                    16.0            19.9
# 4                  47                     7.8             4.6
#
#    HealthInsurPercent  NonEnglishPer  HHMedianIncome  EduHSPer
# 0                90.2            5.4           86667      16.6
# 1                97.1           11.4          117902      13.7
# 2                89.9            4.2          134531      18.4
# 3                66.0           33.0           60060      25.6
# 4                92.0            6.5          143688      14.3

# %%
df1.corr()
# Out:
#                           NAME10  INTPTLAT10  INTPTLON10  Partner Count  \
# NAME10                  1.000000    0.066434   -0.089535      -0.187049
# INTPTLAT10              0.066434    1.000000    0.210002      -0.037024
# INTPTLON10             -0.089535    0.210002    1.000000       0.298223
# Partner Count          -0.187049   -0.037024    0.298223       1.000000
# 2019 FI Rate           -0.056698   -0.075325    0.474387       0.421262
# 2019 FI Population      0.043658   -0.066196    0.371631       0.391996
# PublicTransportPercent -0.624021    0.076407    0.414847       0.317855
# PovertyPercent         -0.319963   -0.013690    0.246564       0.439873
# HealthInsurPercent     -0.266812    0.049272   -0.001019      -0.085903
# NonEnglishPer           0.132983    0.142474   -0.088487       0.041862
# HHMedianIncome          0.002437    0.023027   -0.318693      -0.382492
# EduHSPer                0.205102   -0.164746    0.315073       0.393400
#
#                         2019 FI Rate  2019 FI Population  \
# NAME10                     -0.056698            0.043658
# INTPTLAT10                 -0.075325           -0.066196
# INTPTLON10                  0.474387            0.371631
# Partner Count               0.421262            0.391996
# 2019 FI Rate                1.000000            0.846898
# 2019 FI Population          0.846898            1.000000
# PublicTransportPercent      0.332018            0.203752
# PovertyPercent              0.705489            0.598537
# HealthInsurPercent         -0.148119           -0.240013
# NonEnglishPer              -0.030292            0.060594
# HHMedianIncome             -0.711250           -0.649567
# EduHSPer                    0.708425            0.607217
#
#                         PublicTransportPercent  PovertyPercent  \
# NAME10                               -0.624021       -0.319963
# INTPTLAT10                            0.076407       -0.013690
# INTPTLON10                            0.414847        0.246564
# Partner Count                         0.317855        0.439873
# 2019 FI Rate                          0.332018        0.705489
# 2019 FI Population                    0.203752        0.598537
# PublicTransportPercent                1.000000        0.445927
# PovertyPercent                        0.445927        1.000000
# HealthInsurPercent                    0.103261       -0.283187
# NonEnglishPer                        -0.023003        0.223300
# HHMedianIncome                       -0.310355       -0.634933
# EduHSPer                              0.051200        0.518259
#
#                         HealthInsurPercent  NonEnglishPer  HHMedianIncome  \
# NAME10                           -0.266812       0.132983        0.002437
# INTPTLAT10                        0.049272       0.142474        0.023027
# INTPTLON10                       -0.001019      -0.088487       -0.318693
# Partner Count                    -0.085903       0.041862       -0.382492
# 2019 FI Rate                     -0.148119      -0.030292       -0.711250
# 2019 FI Population               -0.240013       0.060594       -0.649567
# PublicTransportPercent            0.103261      -0.023003       -0.310355
# PovertyPercent                   -0.283187       0.223300       -0.634933
# HealthInsurPercent                1.000000      -0.738061        0.489524
# NonEnglishPer                    -0.738061       1.000000       -0.353436
# HHMedianIncome                    0.489524      -0.353436        1.000000
# EduHSPer                         -0.378710       0.118902       -0.671869
#
#                         EduHSPer
# NAME10                  0.205102
# INTPTLAT10             -0.164746
# INTPTLON10              0.315073
# Partner Count           0.393400
# 2019 FI Rate            0.708425
# 2019 FI Population      0.607217
# PublicTransportPercent  0.051200
# PovertyPercent          0.518259
# HealthInsurPercent     -0.378710
# NonEnglishPer           0.118902
# HHMedianIncome         -0.671869
# EduHSPer                1.000000

# %%
VarY = df[["Partner Count"]] #dependent variable
VarX = sm.add_constant(df[['2019 FI Rate', '2019 FI Population', 
                            'PublicTransportPercent', 'PovertyPercent', 
                            'HealthInsurPercent','NonEnglishPer', 
                            'HHMedianIncome', 'EduHSPer']])

model = sm.OLS(VarY, VarX).fit()
print(df[['2019 FI Rate', '2019 FI Population', 'PublicTransportPercent', 'PovertyPercent', 'HealthInsurPercent','NonEnglishPer', 'HHMedianIncome', 'EduHSPer']].corr)
print(model.summary())
# Out:
# <bound method DataFrame.corr of       2019 FI Rate  2019 FI Population  PublicTransportPercent  \
# 0             10.4                 625                     9.7
# 1              9.1                 282                    17.1
# 2              0.3                  13                     7.3
# 3             10.0                 518                    16.0
# 4              1.6                  47                     7.8
# ...            ...                 ...                     ...
# 1043           7.9                 355                    35.8
# 1044           4.1                 138                    25.7
# 1045           4.8                 287                    18.3
# 1046           5.6                 127                     5.9
# 1047           3.2                 204                     5.7
#
#       PovertyPercent  HealthInsurPercent  NonEnglishPer  HHMedianIncome  \
# 0               16.3                90.2            5.4           86667
# 1                4.7                97.1           11.4          117902
# 2                2.9                89.9            4.2          134531
# 3               19.9                66.0           33.0           60060
# 4                4.6                92.0            6.5          143688
# ...              ...                 ...            ...             ...
# 1043             3.4                98.9            3.3          107325
# 1044             2.0                98.6            0.8          163125
# 1045             2.5                95.8            1.9          121157
# 1046             7.9                91.6           13.0          102500
# 1047             1.2                96.5            2.4          188295
#
#       EduHSPer
# 0         16.6
# 1         13.7
# 2         18.4
# 3         25.6
# 4         14.3
# ...        ...
# 1043       5.1
# 1044       2.6
# 1045       7.3
# 1046      16.8
# 1047      10.9
#
# [1048 rows x 8 columns]>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Partner Count   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     51.00
# Date:                Tue, 28 Apr 2020   Prob (F-statistic):           9.91e-70
# Time:                        17:04:33   Log-Likelihood:                -1518.7
# No. Observations:                1048   AIC:                             3055.
# Df Residuals:                    1039   BIC:                             3100.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -2.3641      0.752     -3.144      0.002      -3.839      -0.889
# 2019 FI Rate              -0.0299      0.011     -2.766      0.006      -0.051      -0.009
# 2019 FI Population         0.0008      0.000      4.084      0.000       0.000       0.001
# PublicTransportPercent     0.0175      0.003      6.390      0.000       0.012       0.023
# PovertyPercent             0.0306      0.006      4.908      0.000       0.018       0.043
# HealthInsurPercent         0.0210      0.008      2.718      0.007       0.006       0.036
# NonEnglishPer              0.0046      0.008      0.582      0.561      -0.011       0.020
# HHMedianIncome         -8.419e-07   1.23e-06     -0.686      0.493   -3.25e-06    1.57e-06
# EduHSPer                   0.0345      0.005      7.007      0.000       0.025       0.044
# ==============================================================================
# Omnibus:                      446.775   Durbin-Watson:                   1.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2959.996
# Skew:                           1.831   Prob(JB):                         0.00
# Kurtosis:                      10.374   Cond. No.                     2.82e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model.resid.plot.kde()

# %%
residuals_name = pd.concat([df1[['NAME10', 'INTPTLAT10' ,'INTPTLON10']], model.resid], axis=1)
residuals_name.sort_values(by=[0])

residuals_name.to_csv('residuals.csv')

# %% [markdown]
# # Plotting outliers on folium map

# %%
# using folium to generate base map in greater DC area

def generateBaseMap(default_location=[38.9072, -77.0369], default_zoom_start=10):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

base_map = generateBaseMap()

# loading in CAFB distribution data
for idx, row in residuals_name.iterrows():
    if(abs(row[0]) > 2):
        c = '#DC143C'
        if row[0] > 0:
            c = '#003366'
            
        lat = float(row['INTPTLAT10'])
        long = float(row['INTPTLON10'])
        folium.CircleMarker( location=[ lat, long ], color=c, radius=2 ).add_to( base_map )

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
logdf = df
logdf['CFAB_existence'] = logdf.apply(lambda row: 1 if row['Partner Count'] > 0 else 0, axis=1)

n_VarY = logdf["CFAB_existence"]

LogModel = sm.Logit(n_VarY, VarX).fit()
LogModel.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.556899
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         CFAB_existence   No. Observations:                 1048
# Model:                          Logit   Df Residuals:                     1039
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 28 Apr 2020   Pseudo R-squ.:                  0.1729
# Time:                        17:04:33   Log-Likelihood:                -583.63
# converged:                       True   LL-Null:                       -705.64
# Covariance Type:            nonrobust   LLR p-value:                 3.189e-48
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -3.0465      1.684     -1.809      0.070      -6.347       0.254
# 2019 FI Rate              -0.0608      0.024     -2.543      0.011      -0.108      -0.014
# 2019 FI Population         0.0013      0.000      3.180      0.001       0.001       0.002
# PublicTransportPercent     0.0395      0.006      6.458      0.000       0.028       0.052
# PovertyPercent             0.0240      0.015      1.586      0.113      -0.006       0.054
# HealthInsurPercent         0.0099      0.017      0.583      0.560      -0.023       0.043
# NonEnglishPer              0.0111      0.017      0.648      0.517      -0.022       0.045
# HHMedianIncome         -4.574e-06   3.22e-06     -1.421      0.155   -1.09e-05    1.73e-06
# EduHSPer                   0.0659      0.011      5.891      0.000       0.044       0.088
# ==========================================================================================
# """
